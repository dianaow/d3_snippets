# %%
import pandas as pd

# %%
links = pd.read_csv('/Users/diana/Documents/dianaow.github.io/forcelayout/data/nodes_edges_sea.csv')

# %%
entity = pd.read_csv('/Users/diana/Documents/dianaow.github.io/forcelayout/data/nodes_filt_entity.csv')

# %%
officer = pd.read_csv('/Users/diana/Documents/dianaow.github.io/forcelayout/data/nodes_officer_sea.csv')

# %%
officer[officer['name'].str.contains('Vandana')]
# Out:
#        node_id                              name country_codes  countries  \
# 998   80135143                Budhrani - Vandana           SGP  Singapore
# 1135  80042465  Budhrani - Devidas N & Vandana D           SGP  Singapore
#
#       status                   sourceID                           valid_until  \
# 998      NaN  Paradise Papers - Appleby  Appleby data is current through 2014
# 1135     NaN  Paradise Papers - Appleby  Appleby data is current through 2014
#
#      note
# 998   NaN
# 1135  NaN

# %%
links[links['START_ID'] == 80135143]
# Out:
#       START_ID                TYPE    END_ID  \
# 3362  80135143  registered_address  81010180
# 3363  80135143  registered_address  81013483
# 3364  80135143          officer_of  82012889
#
#                                       link   start_date     end_date  \
# 3362                       mailing address          NaN          NaN
# 3363  residential address; mailing address          NaN          NaN
# 3364                          secretary of  08-AUG-1979  19-AUG-1988
#
#                        sourceID                           valid_until
# 3362  Paradise Papers - Appleby  Appleby data is current through 2014
# 3363  Paradise Papers - Appleby  Appleby data is current through 2014
# 3364  Paradise Papers - Appleby  Appleby data is current through 2014

# %%
links[links['END_ID'] == 81010180]
# Out:
#       START_ID                TYPE    END_ID             link start_date  \
# 3340  80134649  registered_address  81010180  mailing address        NaN
# 3342  80134653  registered_address  81010180  mailing address        NaN
# 3350  80135121  registered_address  81010180  mailing address        NaN
# 3356  80135124  registered_address  81010180  mailing address        NaN
# 3360  80135127  registered_address  81010180  mailing address        NaN
# 3362  80135143  registered_address  81010180  mailing address        NaN
#
#      end_date                   sourceID                           valid_until
# 3340      NaN  Paradise Papers - Appleby  Appleby data is current through 2014
# 3342      NaN  Paradise Papers - Appleby  Appleby data is current through 2014
# 3350      NaN  Paradise Papers - Appleby  Appleby data is current through 2014
# 3356      NaN  Paradise Papers - Appleby  Appleby data is current through 2014
# ...

# %%
links[links['END_ID'] == 81013483]
# Out:
#       START_ID                TYPE    END_ID  \
# 3345  80135120  registered_address  81013483
# 3351  80135121  registered_address  81013483
# 3363  80135143  registered_address  81013483
# 3745  80042465  registered_address  81013483
# 3747  80042467  registered_address  81013483
# 3749  80042469  registered_address  81013483
#
#                                       link start_date end_date  \
# 3345  mailing address; residential address        NaN      NaN
# 3351  residential address; mailing address        NaN      NaN
# 3363  residential address; mailing address        NaN      NaN
# 3745  mailing address; residential address        NaN      NaN
# 3747  residential address; mailing address        NaN      NaN
# 3749                   residential address        NaN      NaN
#
#                        sourceID                           valid_until
# 3345  Paradise Papers - Appleby  Appleby data is current through 2014
# ...

# %%
entity[entity['node_id'] == 82012889]
# Out:
#       node_id                    name jurisdiction jurisdiction_description  \
# 794  82012889  PACIFIC CREDIT LIMITED           KY           Cayman Islands
#
#     country_codes                 countries incorporation_date  \
# 794       CYM;SGP  Cayman Islands;Singapore        26-APR-1978
#
#      inactivation_date  struck_off_date closed_date ibcRUC status  \
# 794                NaN              NaN         NaN  13463    NaN
#
#      company_type service_provider                   sourceID  \
# 794           NaN          Appleby  Paradise Papers - Appleby
#
#                               valid_until  note
# 794  Appleby data is current through 2014   NaN
